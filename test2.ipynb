# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f = h5py.File('/home/dataset/sift/sift-128-euclidean.hdf5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = h5py.File('/home/dataset/sift/sift-128-euclidean.hdf5')
#
# NameError: name 'h5py' is not defined

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['distances', 'neighbors', 'test', 'train']>

# %%
base = f['train'][:]
queries = f['test'][:]

# %%
bucket_path = "/tmp/buckets.bin"
index_path = "/tmp/test_performance/pagraph"

# %%
gt = f['neighbors']

# %%
# 统计每个桶的命中率
def plot_hit(ax, query = 2025, bucket_path = "/tmp/stat/adapt.txt"):
  gt_i = gt[query]
  rest = set(gt_i)
  hits = []
  issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  for line in lines:
    if line is None:
      break
    line_split = line.split(' ')[:-1]
    line_num = [int(i) for i in line_split]
    issue_size.append(len(line_num))
    hit = set(line_num).intersection(rest)
    hit_number = len(hit)
    rest = rest.difference(hit)
    hits.append (hit_number)
  fb.close()
  
  ax.plot(list(range(1, len(hits) + 1)), list(hits))
  ax.set_xlabel('bucket seq number')
  ax.set_ylabel('hit number')
  ax.set_title("Recall@100 Hit")
  return sum(hits)

# %%
# 统计每个桶的命中率
def plot_hit2(ax, query = 2025, bucket_path = "/tmp/stat/adapt.txt"):
  gt_i = gt[query]
  rest = set(gt_i)
  hits = []
  issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  for line in lines:
    if line is None:
      break
    line_split = line.split(' ')[1:-1]
    line_num = [int(i) for i in line_split]
    issue_size.append(len(line_num))
    hit = set(line_num).intersection(rest)
    hit_number = len(hit)
    rest = rest.difference(hit)
    hits.append (hit_number)
  fb.close()
  
  ax.plot(list(range(1, len(hits) + 1)), list(hits))
  ax.set_xlabel('bucket seq number')
  ax.set_ylabel('hit number')
  ax.set_title("Recall@100 Hit")
  return sum(hits)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
plot_hit(ax[0])
# plot_hit(ax[1], 1024, "/tmp/stat/bucket2.txt")
# plot_hit(ax[2], 2222, "/tmp/stat/bucket.3txt")
# Out:
# 98

# %%
# import matplotlib.pyplot as plt
# plt.plot(list(range(1, len(hits) + 1)), list(reversed(issue_size)))
# plt.plot(list(range(1, len(hits) + 1)), list(reversed(hits)))

# %%
# 统计每个桶的命中率
def dist_fn(v1, v2):
  return np.square(v1 - v2).sum()

def plot_dist(ax, qi = 2025, bucket_path = "/tmp/stat/adapt.txt"):
  query = queries[qi]
  
  # gt_i = gt[query]
  # rest = set(gt_i)
  # hits = []
  # issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  dists = []
  for line in lines:
    if line is None:
      break
    line_split = line.split(' ')[:-1]
    line_num = [int(i) for i in line_split]
    gid = line_num[0]
    dists.append(dist_fn(base[gid], query))
  fb.close()

  ax.plot(list(range(1, len(dists) + 1)), dists)
  ax.set_xlabel('bucket seq number')
  ax.set_ylabel('dist')
  ax.set_title("Recall@100 Hit")

# %%
# 统计每个桶的命中率
def dist_fn(v1, v2):
  return np.square(v1 - v2).sum()

def plot_mean_dist(ax, qi = 2025, bucket_path = "/tmp/stat/adapt.txt"):
  query = queries[qi]
  
  # gt_i = gt[query]
  # rest = set(gt_i)
  # hits = []
  # issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  dists = []
  for line in lines:
    if line is None:
      break

    inner_dists = []
    line_split = line.split(' ')[:-1]
    line_num = [int(i) for i in line_split]
    inner_dists = [dist_fn(base[iid], query) for iid in line_num]
    dists.append(np.mean(inner_dists))
  fb.close()

  ax.plot(list(range(1, len(dists) + 1)), dists)
  ax.set_xlabel('bucket seq number')
  ax.set_ylabel('bucket mean dist')
  ax.set_title("Recall@100 Hit")

# %%
# 统计每个桶的命中率
def dist_fn(v1, v2):
  return np.square(v1 - v2).sum()

def plot_std_dist(ax, qi = 2025, bucket_path = "/tmp/stat/adapt.txt"):
  query = queries[qi]
  
  # gt_i = gt[query]
  # rest = set(gt_i)
  # hits = []
  # issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  dists = []
  for line in lines:
    if line is None:
      break

    inner_dists = []
    line_split = line.split(' ')[:-1]
    line_num = [int(i) for i in line_split]
    inner_dists = [dist_fn(base[iid], query) for iid in line_num]
    dists.append(np.std(inner_dists))
  fb.close()

  ax.plot(list(range(1, len(dists) + 1)), dists)
  ax.set_xlabel('bucket seq number')
  ax.set_ylabel('bucket std dist')
  ax.set_title("Recall@100 Hit")

# %%
# 统计每个桶的命中率
def dist_fn(v1, v2):
  return np.square(v1 - v2).sum()

def plot_all_dist(ax, qi = 2025, bucket_path = "/tmp/stat/adapt.txt"):
  query = queries[qi]
  
  # gt_i = gt[query]
  # rest = set(gt_i)
  # hits = []
  # issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  dists = []
  for line in lines:
    if line is None:
      break

    inner_dists = []
    line_split = line.split(' ')[:-1]
    line_num = [int(i) for i in line_split]
    inner_dists = [dist_fn(base[iid], query) for iid in line_num]
    dists += sorted(inner_dists)
  fb.close()

  ax.plot(list(range(len(dists))), dists)
  ax.set_xlabel('bucket seq number')
  ax.set_ylabel('bucket all dist')
  ax.set_title("Recall@100 Hit")

# %%
def dist_fn(v1, v2):
  return np.square(v1 - v2).sum()

def plot_hit_mean_dist(qi = 2025, bucket_path = "/tmp/stat/adapt.txt"):
  query = queries[qi]
  
  gt_i = gt[qi]
  rest = set(gt_i)

  # issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  dists = []
  hits = []
  for line in lines:
    if line is None:
      break
    line_split = line.split(' ')[:-1]
    line_num = [int(i) for i in line_split]
    hit = set(line_num).intersection(rest)
    # rest = rest.difference(hit)
    if len(hit) > 0:
      hist_dists = [dist_fn(base[iid], query) for iid in hit]
    else:
      hist_dists = [0]
    dists.append(np.mean(hist_dists))
    hits.append(len(hit))
  fb.close()

  fig, ax = plt.subplots()
  ax.set_xlabel('bucket seq number')  
  ax.set_ylabel('mean dist')  
  ax.plot(list(range(len(dists))), dists)

  ax1 = ax.twinx()
  ax1.set_ylabel('hit number')
  ax1.scatter(list(range(len(dists))), hits, color='r', marker='v')

# %%
fig, axes = plt.subplots(3, 3, figsize=(25, 20))
plot_dist(axes[0][0])
plot_hit(axes[1][0])
plot_hit2(axes[2][0])
# plot_mean_dist(axes[2][0])

# plot_dist(axes[0][1], 1024, "/tmp/stat/bucket2.txt")
# plot_hit(axes[1][1], 1024, "/tmp/stat/bucket2.txt")
# # plot_hit2(axes[2][1], 1024, "/tmp/stat/bucket2.txt")
# plot_mean_dist(axes[2][1], 1024, "/tmp/stat/bucket2.txt")

# plot_dist(axes[0][2], 2222, "/tmp/stat/bucket.3txt")
# plot_hit(axes[1][2], 2222, "/tmp/stat/bucket.3txt")
# # plot_hit2(axes[2][2], 2222, "/tmp/stat/bucket2.txt")
# plot_mean_dist(axes[2][2], 2222, "/tmp/stat/bucket.3txt")
# Out:
# 31

# %%
ax = plt.subplot()
plot_all_dist(ax)

# %%
plot_hit_mean_dist()

# %%
def dist_fn(v1, v2):
  return np.square(v1 - v2).sum()

def plot_hit_dist_order(qi = 200, bucket_path = "/tmp/stat/bucket.txt"):
  query = queries[qi]
  
  gt_i = gt[qi]
  rest = set(gt_i)

  # issue_size = []
  fb = open(bucket_path, "r")
  lines = reversed(fb.readlines())
  dists = []
  index = []
  hits = []
  for line in lines:
    if line is None:
      break
    line_split = line.split(' ')[:-1]
    line_num = [int(i) for i in line_split]
    hit = set(line_num).intersection(rest)
    # rest = rest.difference(hit)
    if len(hit) > 0:
      hist_dists = [dist_fn(base[iid], query) for iid in hit]
    
    dists += hist_dists
    sub_index = [list(gt_i).index(x) for x in hit]
    index += sub_index
  fb.close()

  fig, ax = plt.subplots()
  ax.bar(index, dists)
  # ax.set_xlabel('bucket seq number')  
  # ax.set_ylabel('mean dist')  
  # ax.plot(list(range(len(dists))), dists)

  # ax1 = ax.twinx()
  # ax1.set_ylabel('hit number')
  # ax1.scatter(list(range(len(dists))), hits, color='r', marker='v')

# %%
plot_hit_dist_order()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[332], line 1
# ----> 1 plot_hit_dist_order()
#
# Cell In[331], line 32, in plot_hit_dist_order(qi, bucket_path)
#      29 fb.close()
#      31 fig, ax = plt.subplots()
# ---> 32 ax.bar(index, dists)
#
# File ~/miniconda3/envs/plot/lib/python3.10/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/plot/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2520, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2517     if yerr is not None:
#    2518         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2520 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2521     # Make args iterable too.
#    2522     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2524 # Now that units have been converted, set the tick locations.
#    2525 if orientation == 'vertical':
#
# File ~/miniconda3/envs/plot/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~/miniconda3/envs/plot/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (227,) and arg 1 with shape (833,).
